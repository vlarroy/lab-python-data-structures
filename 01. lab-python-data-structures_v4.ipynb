# %% [markdown]
# # Lab | Data Structures

# %% [markdown]
# ## Exercise: Managing Customer Orders
#
# As part of a business venture, you are starting an online store that sells various products. To ensure smooth operations, you need to develop a program that manages customer orders and inventory.
#
# Follow the steps below to complete the exercise:
#
# 1. Define a list called `products` that contains the following items: "t-shirt", "mug", "hat", "book", "keychain".
#
# 2. Create an empty dictionary called `inventory`. ##set a new variable and a empty dictionary
#
# 3. Ask the user to input the quantity of each product available in the inventory. Use the product names from the `products` list as keys in the `inventory` dictionary and assign the respective quantities as values.
#
# 4. Create an empty set called `customer_orders`.
#
# 5. Ask the user to input the name of three products that a customer wants to order (from those in the products list, meaning three products out of "t-shirt", "mug", "hat", "book" or "keychain". Add each product name to the `customer_orders` set.
#
# 6. Print the products in the `customer_orders` set.
#
# 7. Calculate the following order statistics:
#    - Total Products Ordered: The total number of products in the `customer_orders` set.
#    - Percentage of Products Ordered: The percentage of products ordered compared to the total available products.
#
#    Store these statistics in a tuple called `order_status`.
#
# 8. Print the order statistics using the following format:
#    ```
#    Order Statistics:
#    Total Products Ordered: <total_products_ordered>
#    Percentage of Products Ordered: <percentage_ordered>%
#    ```
#
# 9. Update the inventory by subtracting 1 from the quantity of each product. Modify the `inventory` dictionary accordingly.
#
# 10. Print the updated inventory, displaying the quantity of each product on separate lines.
#
# Solve the exercise by implementing the steps using the Python concepts of lists, dictionaries, sets, and basic input/output operations.

# %%
##1. Define a list called `products` that contains the following items: "t-shirt", "mug", "hat", "book", "keychain".
products = ["t-shirt", "mug", "hat", "book", "keychain"]

## 2. Create an empty dictionary called `inventory`. ##set a new variable and a empty dictionary
inventory = {}

##3. Ask the user to input the quantity of each product available in the inventory.
#Use the product names from the `products` list as keys in the `inventory` dictionary and assign the respective quantities as values.

for item in products:
     num = int(input("please, enter the quantity for this product: "))
     inventory[item] = num
     
print(inventory)
# Out:
# {'t-shirt': 1, 'mug': 2, 'hat': 3, 'book': 4, 'keychain': 5}

# %%
#4. Create an empty set called `customer_orders`.
customer_orders = []


# 5. Ask the user to input the name of three products that a customer wants to order (from those in the products list, meaning three products out of "t-shirt", "mug", "hat", "book" or "keychain". 
#Add each product name to the `customer_orders` set.

while customer_choice not in products or len(customer_orders) < 3: 
    customer_choice = input("please, write the name of a product: ")
    if customer_choice in products:
        customer_orders.append(customer_choice)
    else:
        print(f"{customer_choice} is not a valid product, it must be {', '.join(products)}")
#6. Print the products in the `customer_orders` set.
print(customer_orders)
# Out:
# gun is not a valid product, it must be t-shirt, mug, hat, book, keychain
# ['hat', 'mug', 'book']

# %%
#7. Calculate the following order statistics:
#- Total Products Ordered: The total number of products in the `customer_orders` set.

item = 0
total_items = 0 


products_ordered = {'book', 'mug', 'hat'}
inventory = {'t-shirt': 1, 'mug': 2, 'hat': 3, 'book': 4, 'keychain': 5}
my_list = list(inventory.values())

for item in my_list:
    total_items = total_items + item


# Percentage of Products Ordered: The percentage of products ordered compared to the total available products.
total_products_ordered = len(products_ordered)

percentage_of_products_ordered = ((len(products_ordered)) / total_items)*100
print(percentage_of_products_ordered)

#Store these statistics in a tuple called `order_status`.
order_status = (total_items, total_products_ordered, percentage_of_products_ordered)
print(order_status)
# Out:
# 20.0
# (15, 3, 20.0)

# %% [markdown]
# COORECTED, EASIER VERSION

# %%
products_ordered = {'book', 'mug', 'hat'} 
inventory = {'t-shirt': 1, 'mug': 2, 'hat': 3, 'book': 4, 'keychain': 5}
 
all_stock = 0 
user_stock =len(products_ordered) #the user_stock is the products that the products ordered
products_stock = list(inventory.values()) #in order to calculate the total products that I have in stock, first, we need to create a list with all the values of the products keys that are in the dictionary.


for product_stock in products_stock:
    all_stock += product_stock

percentage = (user_stock / all_stock)*100

order_status = (all_stock, user_stock, percentage)

print(order_status)
# Out:
# (15, 3, 20.0)

# %%
#9. Update the inventory by subtracting 1 from the quantity of each product ordered. Modify the `inventory` dictionary accordingly.
inventory = {'t-shirt': 1, 'mug': 2, 'hat': 3, 'book': 4, 'keychain': 5}
products_ordered = {'book', 'mug', 'hat'}

for product in products_ordered:
        if inventory[item] < 1:
            print("out of Stock")
        else:
            inventory[item]-=1
print(inventory)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 6
#       3 products_ordered = {'book', 'mug', 'hat'}
#       5 for product in products_ordered:
# ----> 6         if inventory[item] < 1:
#       7             print("out of Stock")
#       8         else:
#
# KeyError: 5

# %%
for key, value in inventory.items():
    print(f"you have {value} {key}")
# Out:
# you have 1 t-shirt
# you have 2 mug
# you have 3 hat
# you have 4 book
# you have 5 keychain
